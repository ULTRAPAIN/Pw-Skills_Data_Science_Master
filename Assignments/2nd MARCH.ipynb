# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a popular data visualization library in Python that provides a wide range of tools for creating various types of plots and charts. It is widely used in data analysis, scientific research, and other fields for visualizing data and gaining insights from it.
#
# Matplotlib offers a flexible and comprehensive framework for generating high-quality plots with a wide variety of customization options. It allows users to create line plots, bar plots, scatter plots, histograms, pie charts, and many other types of visualizations.
#
# Here are five common plots that can be created using the Pyplot module of Matplotlib:
#
# Line Plot: A line plot is created using the plot() function and is useful for visualizing the trend or relationship between two variables over a continuous range.
#
# Bar Plot: A bar plot is created using the bar() or barh() function and is suitable for comparing and displaying the categorical data as rectangular bars. It can be used to compare different categories or groups.
#
# Scatter Plot: A scatter plot is created using the scatter() function and is used to visualize the relationship between two continuous variables. It represents data points as individual markers on a two-dimensional plane.
#
# Histogram: A histogram is created using the hist() function and is used to visualize the distribution of a continuous variable. It divides the data into equal bins and displays the frequency or count of data points falling into each bin.
#
# Pie Chart: A pie chart is created using the pie() function and is used to represent the composition or proportion of different categories as slices of a circular pie. It is suitable for displaying categorical data with relative frequencies or proportions

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %% [markdown]
# A scatter plot is created using the scatter() function and is used to visualize the relationship between two continuous variables. It represents data points as individual markers on a two-dimensional plane.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.random.rand(10)
y=np.random.rand(10)

# %%
plt.scatter(x,y)

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.xlabel("X data")
plt.ylabel("Y data")
plt.scatter(x,y)

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to divide the figure into multiple smaller plots, each with its own set of axes. This function is useful when you want to display multiple plots side by side or in a grid layout, allowing for easy comparison or visualization of different data or aspects of the same data.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)  
plt.plot(x1, y1)
plt.title("Line 1")

plt.subplot(2, 2, 2)  
plt.plot(x2, y2)
plt.title("Line 2")

plt.subplot(2, 2, 3)  
plt.plot(x3, y3)
plt.title("Line 3")

plt.subplot(2, 2, 4)  
plt.plot(x4, y4)
plt.title("Line 4")

plt.tight_layout()  

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot is created using the bar() or barh() function and is suitable for comparing and displaying the categorical data as rectangular bars. It can be used to compare different categories or groups.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(x=company,height=profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=company,width=profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a statistical visualization technique that provides a summary of the distribution of a dataset. It is used to display the median, quartiles, and potential outliers of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

plt.boxplot(data)
plt.xticks([1, 2], ['Box 1', 'Box 2'])
plt.xlabel('Box')
plt.ylabel('Values')
plt.title('Box Plot')

plt.show()
